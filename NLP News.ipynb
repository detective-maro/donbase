# %%
import requests
from bs4 import BeautifulSoup
from textblob import TextBlob
from datetime import datetime
import nltk
from nltk import word_tokenize, pos_tag

# Download NLTK resources
nltk.download('punkt')
nltk.download('averaged_perceptron_tagger')

# Function to perform sentiment analysis
def analyze_sentiment(text):
    analysis = TextBlob(text)
    # Get the sentiment polarity score
    sentiment_score = analysis.sentiment.polarity
    # Assigning sentiment label based on polarity score
    if sentiment_score > 0:
        sentiment_label = 'Positive'
    elif sentiment_score == 0:
        sentiment_label = 'Neutral'
    else:
        sentiment_label = 'Negative'
    # Get the reason for sentiment score
    if sentiment_score > 0.2:
        reason = 'Strongly positive'
    elif sentiment_score > 0:
        reason = 'Somewhat positive'
    elif sentiment_score == 0:
        reason = 'Neutral'
    elif sentiment_score > -0.2:
        reason = 'Somewhat negative'
    else:
        reason = 'Strongly negative'
    return sentiment_label, sentiment_score, reason

# Function to extract nouns from the headline
def extract_nouns_from_headline(headline):
    tokens = word_tokenize(headline)
    tagged = pos_tag(tokens)
    nouns = [word for word, pos in tagged if pos.startswith('NN')]
    return nouns

# Function to get headlines from URL and perform sentiment analysis
def analyze_headlines_from_url(url):
    # Retrieve HTML content of the webpage
    response = requests.get(url)
    soup = BeautifulSoup(response.text, 'html.parser')
    
    # Extract headlines, datetime stamps, and article URLs
    headlines_data = []
    for article in soup.find_all('a', class_='article-link'):
        headline = article.find('h3', class_='article-name').text.strip()
        datetime_stamp = article.find('time', class_='date-with-prefix')['datetime']
        article_url = article['href']
        # Perform sentiment analysis of the headline
        sentiment_label, sentiment_score, reason = analyze_sentiment(headline)
        # Extract nouns from headline and use them as tags
        tags = extract_nouns_from_headline(headline)
        headlines_data.append({'headline': headline, 'sentiment_label': sentiment_label, 'sentiment_score': sentiment_score, 'reason': reason, 'datetime': datetime_stamp, 'tags': tags})
    
    return headlines_data

# URL of the webpage containing headlines
url = 'https://www.space.com/search?searchTerm=webb'

# Analyze headlines and sentiment from the URL
headlines_data = analyze_headlines_from_url(url)

# Print results
for headline_data in headlines_data:
    print("Title:", headline_data['headline'])
    print("Sentiment Label:", headline_data['sentiment_label'])
    print("Sentiment Score:", headline_data['sentiment_score'])
    print("Reason:", headline_data['reason'])
    print("Datetime:", headline_data['datetime'])
    print("Tags:", headline_data['tags'])
    print()
# Out:
# [nltk_data] Downloading package punkt to
# [nltk_data]     C:\Users\DonGaspar\AppData\Roaming\nltk_data...
# [nltk_data]   Package punkt is already up-to-date!
# [nltk_data] Downloading package averaged_perceptron_tagger to
# [nltk_data]     C:\Users\DonGaspar\AppData\Roaming\nltk_data...
# [nltk_data]   Package averaged_perceptron_tagger is already up-to-
# [nltk_data]       date!
# Title: James Webb Space Telescope uncovers massive sunshield in next step of risky deployment
# Sentiment Label: Neutral
# Sentiment Score: 0.0
# Reason: Neutral
# Datetime: 2021-12-30T20:22:53Z
# Tags: ['James', 'Webb', 'Space', 'Telescope', 'uncovers', 'sunshield', 'step', 'deployment']
#
# Title: James Webb: Early NASA Visionary
# Sentiment Label: Positive
# Sentiment Score: 0.1
# Reason: Somewhat positive
# Datetime: 2017-11-22T02:49:15Z
# Tags: ['James', 'Webb', 'NASA', 'Visionary']
#
# Title: James Webb Space Telescope arrives at new home in space
# Sentiment Label: Positive
# Sentiment Score: 0.13636363636363635
# Reason: Somewhat positive
# Datetime: 2022-01-24T22:12:38Z
# Tags: ['James', 'Webb', 'Space', 'Telescope', 'home', 'space']
#
# Title: Paint it black: behind the James Webb Space Telescope's signature color
# Sentiment Label: Negative
# Sentiment Score: -0.2833333333333333
# Reason: Strongly negative
# Datetime: 2022-02-08T21:53:19Z
# Tags: ['Paint', 'James', 'Webb', 'Space', 'Telescope', 'signature', 'color']
#
# Title: Building the James Webb Space Telescope: Hubble's Successor (Gallery)
# Sentiment Label: Neutral
# Sentiment Score: 0.0
# Reason: Neutral
# Datetime: 2016-12-10T15:15:00Z
# Tags: ['James', 'Webb', 'Space', 'Telescope', 'Hubble', 'Successor', 'Gallery']
#
# Title: NASA to release new James Webb Space Telescope images in update today. Here's when to look.
# Sentiment Label: Positive
# Sentiment Score: 0.13636363636363635
# Reason: Somewhat positive
# Datetime: 2022-03-16T21:24:29Z
# Tags: ['NASA', 'James', 'Webb', 'Space', 'Telescope', 'images', 'today']
#
# Title: James Webb Space Telescope's powers will be revealed in just weeks and scientists can't wait
# Sentiment Label: Neutral
# Sentiment Score: 0.0
# Reason: Neutral
# Datetime: 2022-06-30T15:58:55Z
# Tags: ['James', 'Webb', 'Space', 'Telescope', 'powers', 'weeks', 'scientists']
#
# Title: This amazing HD video is the last view we'll ever have of the James Webb Space Telescope
# Sentiment Label: Positive
# Sentiment Score: 0.30000000000000004
# Reason: Strongly positive
# Datetime: 2022-01-06T11:57:28Z
# Tags: ['HD', 'video', 'view', 'James', 'Webb', 'Space', 'Telescope']
#
# Title: Watch the James Webb Space Telescope's last days on Earth in this time-lapse video
# Sentiment Label: Neutral
# Sentiment Score: 0.0
# Reason: Neutral
# Datetime: 2022-01-25T11:00:14Z
# Tags: ['James', 'Webb', 'Space', 'Telescope', 'days', 'Earth', 'video']
#
# Title: NASA's James Webb Space Telescope mission — Live updates
# Sentiment Label: Positive
# Sentiment Score: 0.13636363636363635
# Reason: Somewhat positive
# Datetime: 2024-02-29T09:06:15Z
# Tags: ['NASA', 'James', 'Webb', 'Space', 'Telescope', 'mission', '—', 'Live', 'updates']

# %%
#pip install requests beautifulsoup4 textblob
import requests
from bs4 import BeautifulSoup
from textblob import TextBlob

# %%
import requests
from bs4 import BeautifulSoup

# Function to get news data
def get_news_data():
    # Set headers to mimic a browser visit
    headers = {
        "User-Agent": "Mozilla/5.0 (Windows NT 10.0; Win64; x64) AppleWebKit/537.36 (KHTML, like Gecko) Chrome/58.0.3029.110 Safari/537.3"
    }

    # Google News URL
    news_url = "https://news.google.com/news/rss"

    # Make an HTTP request to the URL
    response = requests.get(news_url, headers=headers)

    # Parse the XML content of the response
    soup = BeautifulSoup(response.content, features="xml")

    # Find all news items
    news_items = soup.findAll('item')

    # List to hold news data
    news_data = []

    # Extract title, link, and publish date for each news item
    for item in news_items:
        news_data.append({
            "title": item.title.text,
            "link": item.link.text,
            "pubDate": item.pubDate.text
        })

    return news_data

# Function to print news data
def print_news_data(news_data):
    for news in news_data:
        print(f"Title: {news['title']}")
        print(f"Link: {news['link']}")
        print(f"Publish Date: {news['pubDate']}")
        print("-" * 60)

# Get news data
news_data = get_news_data()

# Print news data
print_news_data(news_data)
# Out:
# Title: Nikki Haley suspends election 2024 campaign - The Associated Press
# Link: https://news.google.com/rss/articles/CBMibWh0dHBzOi8vYXBuZXdzLmNvbS9hcnRpY2xlL25pa2tpLWhhbGV5LXJlcHVibGljYW4tdHJ1bXAtc3VwZXItdHVlc2RheS1sb3NzZXMtOTVhYjU2YjY4YThlZWZiYmYwNGVmOTBmMmYwMGVmMjnSAQA?oc=5
# Publish Date: Wed, 06 Mar 2024 17
AA?oc=5
# Publish Date: Wed, 06 Mar 2024 18:00:00 GMT
# ------------------------------------------------------------
# Title: Arctic to Lose All its Ice Within Next Decade: Study | Vantage with Palki Sharma - Firstpost
# Link: https://news.google.com/rss/articles/CCAiC25fWlZ0V3ZWMHQ4mAEB?oc=5
# Publish Date: Wed, 06 Mar 2024 18:10:00 GMT
# ------------------------------------------------------------
# Title: Juno's Groundbreaking Discovery: Surprising Oxygen Insights From Europa's Close Flyby - SciTechDaily
# Link: https://news.google.com/rss/articles/CBMibGh0dHBzOi8vc2NpdGVjaGRhaWx5LmNvbS9qdW5vcy1ncm91bmRicmVha2luZy1kaXNjb3Zlcnktc3VycHJpc2luZy1veHlnZW4taW5zaWdodHMtZnJvbS1ldXJvcGFzLWNsb3NlLWZseWJ5L9IBAA?oc=5
# Publish Date: Wed, 06 Mar 2024 08:48:05 GMT
# ------------------------------------------------------------
# Title: NASA Concerned as Voyager 1 Sending Back Incomprehensible Code - Futurism
# Link: https://news.google.com/rss/articles/CBMiQmh0dHBzOi8vZnV0dXJpc20uY29tL3RoZS1ieXRlL25hc2Etdm95YWdlci0xLWluY29tcHJlaGVuc2libGUtY29kZdIBAA?oc=5
# Publish Date: Wed, 06 Mar 2024 17:32:34 GMT
# ------------------------------------------------------------
# Title: Healthy Returns: What to know about CDC’s new Covid recommendations - CNBC
# Link: https://news.google.?oc=5
# Publish Date: Wed, 06 Mar 2024 17:08:59 GMT
# ------------------------------------------------------------
# Title: A man deliberately got 217 Covid shots. Here’s what happened - CNN
# Link: https://news.google.?oc=5
# Publish Date: Wed, 06 Mar 2024 16:16:00 GMT
# ------------------------------------------------------------
# Title: COVID-19 leaves its mark on the brain, including with significant drops in IQ scores - PsyPost
# Link: https://news.google.com/rss/articles/CBMibGh0dHBzOi8vd3d3LnBzeXBvc3Qub3JnL2NvdmlkLTE5LWxlYXZlcy1pdHMtbWFyay1vbi10aGUtYnJhaW4taW5jbHVkaW5nLXdpdGgtc2lnbmlmaWNhbnQtZHJvcHMtaW4taXEtc2NvcmVzL9IBAA?oc=5
# Publish Date: Tue, 05 Mar 2024 19:01:53 GMT
# ------------------------------------------------------------
# Title: American Indian Cancer Foundation Launches Sixth Annual Blue Beads Campaign for National Colorectal Cancer Awareness Month - Yahoo Life
# Link: https://news.google.com/rss/articles/CBMiWWh0dHBzOi8vd3d3LnlhaG9vLmNvbS9saWZlc3R5bGUvYW1lcmljYW4taW5kaWFuLWNhbmNlci1mb3VuZGF0aW9uLWxhdW5jaGVzLTEzMzMyMzk0NC5odG1s0gEA?oc=5
# Publish Date: Tue, 05 Mar 2024 13:33:23 GMT
# ------------------------------------------------------------

# %%
import requests
from bs4 import BeautifulSoup
from nltk.sentiment.vader import SentimentIntensityAnalyzer
from datetime import datetime
import nltk
from nltk import word_tokenize, pos_tag

# Download NLTK resources
nltk.download('punkt')
nltk.download('averaged_perceptron_tagger')
nltk.download('vader_lexicon')

# Initialize VADER
sid = SentimentIntensityAnalyzer()

# Function to perform sentiment analysis using VADER
def analyze_sentiment_vader(text):
    # Get sentiment scores
    sentiment_scores = sid.polarity_scores(text)
    # Determine sentiment label based on compound score
    if sentiment_scores['compound'] >= 0.05:
        sentiment_label = 'Positive'
    elif sentiment_scores['compound'] <= -0.05:
        sentiment_label = 'Negative'
    else:
        sentiment_label = 'Neutral'
    return sentiment_label, sentiment_scores['compound']

# Function to get news data from Google News
def get_news_data():
    # Set headers to mimic a browser visit
    headers = {
        "User-Agent": "Mozilla/5.0 (Windows NT 10.0; Win64; x64) AppleWebKit/537.36 (KHTML, like Gecko) Chrome/58.0.3029.110 Safari/537.3"
    }

    # Google News URL
    news_url = "https://news.google.com/news/rss"

    # Make an HTTP request to the URL
    response = requests.get(news_url, headers=headers)

    # Parse the XML content of the response
    soup = BeautifulSoup(response.content, features="xml")

    # Find all news items
    news_items = soup.findAll('item')

    # List to hold news data
    news_data = []

    # Extract title, link, and publish date for each news item
    for item in news_items:
        news_data.append({
            "title": item.title.text,
            "link": item.link.text,
            "pubDate": item.pubDate.text
        })

    return news_data

# Function to print news data
def print_news_data(news_data):
    for news in news_data:
        print(f"Title: {news['title']}")
        print(f"Link: {news['link']}")
        print(f"Publish Date: {news['pubDate']}")
        print("-" * 60)

# Analyze headlines and sentiment from the Google News titles using VADER
def analyze_headlines_from_google_news():
    # Get news data from Google News
    news_data = get_news_data()

    # List to hold analyzed headlines
    headlines_data = []

    # Analyze sentiment for each headline
    for news in news_data:
        headline = news['title']
        # Perform sentiment analysis using VADER
        sentiment_label, sentiment_score = analyze_sentiment_vader(headline)
        headlines_data.append({'headline': headline, 'sentiment_label': sentiment_label, 'sentiment_score': sentiment_score, 'link': news['link'], 'pubDate': news['pubDate']})
    
    return headlines_data

# Analyze headlines from Google News
headlines_data = analyze_headlines_from_google_news()

# Print results
for headline_data in headlines_data:
    print("Title:", headline_data['headline'])
    print("Sentiment Label:", headline_data['sentiment_label'])
    print("Sentiment Score:", headline_data['sentiment_score'])
    print("Link:", headline_data['link'])
    print("Publish Date:", headline_data['pubDate'])
    print()
# Out:
# [nltk_data] Downloading package punkt to
# [nltk_data]     C:\Users\DonGaspar\AppData\Roaming\nltk_data...
# [nltk_data]   Package punkt is already up-to-date!
# [nltk_data] Downloading package averaged_perceptron_tagger to
# [nltk_data]     C:\Users\DonGaspar\AppData\Roaming\nltk_data...
# [nltk_data]   Package averaged_perceptron_tagger is already up-to-
# [nltk_data]       date!
# [nltk_data] Downloading package vader_lexicon to
# [nltk_data]     C:\Users\DonGaspar\AppData\Roaming\nltk_data...
# [nltk_data]   Package vader_lexicon is already up-to-date!
# Title: Nikki Haley ends White House bid, clearing path for a Trump-Biden rematch - Reuters
# Sentiment Label: Neutral
# Sentiment Score: 0.0
# Link: https://news.google.com/rss/articles/CBMib2h0dHBzOi8vd3d3LnJldXRlcnMuY29tL3dvcmxkL3VzL25pa2tpLWhhbGV5LWVuZHMtd2hpdGUtaG91c2UtYmlkLWNsZWFyaW5nLXBhdGgtdHJ1bXAtYmlkZW4tcmVtYXRjaC0yMDI0LTAzLTA2L9IBAA?oc=5
# Publish Date: Wed, 06 Mar 2024 20:00:25 GMT
#
# Title: Crew members killed for first time in Houthi attack on commercial ship near Yemen, US officials say - CNN
# Sentiment Label: Negative
# Sentiment Score: -0.8225
# Link: https://news.google.?oc=5
# Publish Date: Wed, 06 Mar 2024 18:47:00 GMT
#
# Title: Trump’s on the ballot, but the Supreme Court left key constitutional questions unanswered - CNN
# Sentiment Label: Positive
# Sentiment Score: 0.7096
# Link: https://news.google.?oc=5
# Publish Date: Wed, 06 Mar 2024 16:36:00 GMT
#
# Title: Ukraine war: Explosions hit Odesa as Zelensky meets Greek PM - BBC.com
# Sentiment Label: Negative
# Sentiment Score: -0.5994
# Link: https://news.google.com/rss/articles/CBMiLmh0dHBzOi8vd3d3LmJiYy5jb20vbmV3cy93b3JsZC1ldXJvcGUtNjg0OTI2ODjSATJodHRwczovL3d3dy5iYmMuY29tL25ld3Mvd29ybGQtZXVyb3BlLTY4NDkyNjg4LmFtcA?oc=5
# Publish Date: Wed, 06 Mar 2024 19:00:36 GMT
#
# Title: Tesla CEO Elon Musk says he's not donating money to Trump or Biden - CNBC
# Sentiment Label: Neutral
# Sentiment Score: 0.0
# Link: https://news.google.com/rss/articles/CBMiZmh0dHBzOi8vd3d3LmNuYmMuY29tLzIwMjQvMDMvMDYvdGVzbGEtY2VvLWVsb24tbXVzay1zYXlzLWhlcy1ub3QtZG9uYXRpbmctbW9uZXktdG8tdHJ1bXAtb3ItYmlkZW4uaHRtbNIBAA?oc=5
# Publish Date: Wed, 06 Mar 2024 15:26:53 GMT
#
# Title: Budget 2024: Jeremy Hunt cuts National Insurance again as election looms - BBC.com
# Sentiment Label: Negative
# Sentiment Score: -0.4215
# Link: https://news.google.com/rss/articles/CBMiLWh0dHBzOi8vd3d3LmJiYy5jb20vbmV3cy91ay1wb2xpdGljcy02ODQ4ODQ2N9IBMWh0dHBzOi8vd3d3LmJiYy5jb20vbmV3c
# Publish Date: Wed, 06 Mar 2024 15:19:38 GMT
#
# Title: Israel Hamas war live updates: Hopes for Gaza cease-fire dim - USA TODAY
# Sentiment Label: Negative
# Sentiment Score: -0.2732
# Link: https://news.google.com/rss/articles/CBMicWh0dHBzOi8vd3d3LnVzYXRvZGF5LmNvbS9zdG9yeS9uZXdzL3dvcmxkL2lzcmFlbC1oYW1hcy8yMDI0LzAzLzA2L2lzcmFlbC1oYW1hcy13YXItZ2F6YS1saXZlLXVwZGF0ZXMvNzI4NjM4MzcwMDcv0gEA?oc=5
# Publish Date: Wed, 06 Mar 2024 20:37:30 GMT
#
# Title: Too Little Ammunition, Too Many Russians: The Harrowing Retreat from Avdiivka - Yahoo! Voices
# Sentiment Label: Positive
# Sentiment Score: 0.2714
# Link: https://news.google.com/rss/articles/CBMiSGh0dHBzOi8vd3d3LnlhaG9vLmNvbS9uZXdzL3Rvby1saXR0bGUtYW1tdW5pdGlvbi10b28tbWFueS0xMzIzNDk3MTEuaHRtbNIBAA?oc=5
# Publish Date: Wed, 06 Mar 2024 13:23:49 GMT
#
# Title: China is 'deliberately stirring up trouble' in the South China Sea, Philippines says - NBC News
# Sentiment Label: Negative
# Sentiment Score: -0.4019
# Link: https://news.google.com/rss/articles/CBMibWh0dHBzOi8vd3d3Lm5iY25ld3MuY29tL25ld3Mvd29ybGQvY2hpbmEtZGVsaWJlcmF0ZWx5LXN0aXJyaW5nLXRyb3VibGUtc291dGgtY2hpbmEtc2VhLXBoaWxpcHBpbmVzLXJjbmExNDE5ODjSAStodHRwczovL3d3dy5uYmNuZXdzLmNvbS9uZXdzL2FtcC9yY25hMTQxOTg4?oc=5
# Publish Date: Wed, 06 Mar 2024 10:33:34 GMT
#
# Title: Embattled lender NYCB secures $1 bln investment from cohort including Mnuchin's firm - Reuters
# Sentiment Label: Positive
# Sentiment Score: 0.3182
# Link: https://news.google.com/rss/articles/CBMiZGh0dHBzOi8vd3d3LnJldXRlcnMuY29tL21hcmtldHMvdXMvZW1iYXR0bGVkLWxlbmRlci1ueWNiLXNlZWtzLWNhc2gtaW5mdXNpb24td3NqLXJlcG9ydHMtMjAyNC0wMy0wNi_SAQA?oc=5
# Publish Date: Wed, 06 Mar 2024 19:47:00 GMT
#
# Title: Key takeaways from Fed Chair Powell’s testimony on Capitol Hill - CNN
# Sentiment Label: Neutral
# Sentiment Score: 0.0
# Link: https://news.google.?oc=5
# Publish Date: Wed, 06 Mar 2024 20:03:45 GMT
#
# Title: Exclusive: US regulators expected to significantly reduce Basel capital burden - Reuters
# Sentiment Label: Negative
# Sentiment Score: -0.34
# Link: https://news.google.com/rss/articles/CBMie2h0dHBzOi8vd3d3LnJldXRlcnMuY29tL21hcmtldHMvdXMvdXMtcmVndWxhdG9ycy1leHBlY3RlZC1zaWduaWZpY2FudGx5LXJlZHVjZS1iYXNlbC1jYXBpdGFsLWJ1cmRlbi1zb3VyY2VzLXNheS0yMDI0LTAzLTA2L9IBAA?oc=5
# Publish Date: Wed, 06 Mar 2024 17:16:00 GMT
#
# Title: SEC Adopts Rules to Enhance and Standardize Climate-Related Disclosures for Investors - SEC.gov
# Sentiment Label: Positive
# Sentiment Score: 0.1779
# Link: https://news.google.com/rss/articles/CBMiLmh0dHBzOi8vd3d3LnNlYy5nb3YvbmV3cy9wcmVzcy1yZWxlYXNlLzIwMjQtMzHSAQA?oc=5
# Publish Date: Wed, 06 Mar 2024 17:19:18 GMT
#
# Title: Microsoft AI engineer warns FTC about Copilot Designer safety concerns - The Verge
# Sentiment Label: Positive
# Sentiment Score: 0.34
# Link: https://news.google.com/rss/articles/CBMiZWh0dHBzOi8vd3d3LnRoZXZlcmdlLmNvbS8yMDI0LzMvNi8yNDA5MjE5MS9taWNyb3NvZnQtYWktZW5naW5lZXItY29waWxvdC1kZXNpZ25lci1mdGMtc2FmZXR5LWNvbmNlcm5z0gEA?oc=5
# Publish Date: Wed, 06 Mar 2024 16:29:05 GMT
#
# Title: Apple terminates Epic Games developer account calling it a ‘threat’ to the iOS ecosystem - TechCrunch
# Sentiment Label: Neutral
# Sentiment Score: 0.0
# Link: https://news.google.com/rss/articles/CBMieWh0dHBzOi8vdGVjaGNydW5jaC5jb20vMjAyNC8wMy8wNi9hcHBsZS10ZXJtaW5hdGVzLWVwaWMtZ2FtZXMtZGV2ZWxvcGVyLWFjY291bnQtY2FsbGluZy1pdC1hLXRocmVhdC10by10aGUtaW9zLWVjb3N5c3RlbS_SAQA?oc=5
# Publish Date: Wed, 06 Mar 2024 17:09:21 GMT
#
# Title: Google Suddenly Adds Nest And Fitbit To Google One Subscription - Forbes
# Sentiment Label: Neutral
# Sentiment Score: 0.0
# Link: https://news.google.?oc=5
# Publish Date: Wed, 06 Mar 2024 17:49:43 GMT
#
# Title: Xbox Partner Preview March 2024: Everything Announced - IGN
# Sentiment Label: Neutral
# Sentiment Score: 0.0
# Link: https://news.google.com/rss/articles/CBMiUWh0dHBzOi8vd3d3Lmlnbi5jb20vYXJ0aWNsZXMveGJveC1wYXJ0bmVyLXByZXZpZXctbWFyY2gtMjAyNC1ldmVyeXRoaW5nLWFubm91bmNlZNIBAA?oc=5
# Publish Date: Wed, 06 Mar 2024 18:56:15 GMT
#
# Title: 'I'm still embarrassed': guess what actors said about major movie flops - The Guardian
# Sentiment Label: Negative
# Sentiment Score: -0.34
# Link: https://news.google.com/rss/articles/CBMiWWh0dHBzOi8vd3d3LnRoZWd1YXJkaWFuLmNvbS9maWxtLzIwMjQvbWFyLzA2L3F1aXotd2hhdC1hY3RvcnMtc2FpZC1tb3ZpZS1mbG9wcy1tYWRhbWUtd2Vi0gEA?oc=5
# Publish Date: Wed, 06 Mar 2024 18:45:00 GMT
#
# Title: ‘Sister Wives’ star Janelle Brown was concerned by son Garrison's final texts before he died - Page Six
# Sentiment Label: Negative
# Sentiment Score: -0.5574
# Link: https://news.google....?oc=5
# Publish Date: Wed, 06 Mar 2024 19:10:00 GMT
#
# Title: The 100 Best Beatles Songs From Their Solo Careers - Rolling Stone
# Sentiment Label: Positive
# Sentiment Score: 0.6369
# Link: https://news.google.com/rss/articles/CBMiUmh0dHBzOi8vd3d3LnJvbGxpbmdzdG9uZS5jb20vbXVzaWMvbXVzaWMtbGlzdHMvYmVzdC1iZWF0bGVzLXNvbG8tc29uZ3MtMTIzNDk3Mjc1OC_SAQA?oc=5
# Publish Date: Wed, 06 Mar 2024 17:23:02 GMT
#
# Title: Star Wars & Harry Potter Composer John Williams Reveals How He Came Up With Cinemas Biggest Scores - Variety
# Sentiment Label: Negative
# Sentiment Score: -0.5574
# Link: https://news.google.com/rss/articles/CCAiC2NHOVpfNUZ6TUNvmAEB?oc=5
# Publish Date: Wed, 06 Mar 2024 16:00:32 GMT
#
# Title: 2024 NFL Free Agency: Top Values at Every Position for Teams to Target This Offseason - Bleacher Report
# Sentiment Label: Positive
# Sentiment Score: 0.7783
# Link: https://news.google.?oc=5
# Publish Date: Wed, 06 Mar 2024 12:32:54 GMT
#
# Title: Justin Fields trade rumors: This QB-needy team is already out on a potential deal for Bears signal-caller - CBS Sports
# Sentiment Label: Neutral
# Sentiment Score: 0.0
# Link: https://news.google....?oc=5
# Publish Date: Wed, 06 Mar 2024 17:11:00 GMT
#
# Title: 'Scary and Daunting': Dartmouth Players Detail How Union Plan Came Together - The New York Times
# Sentiment Label: Negative
# Sentiment Score: -0.4939
# Link: https://news.google.com/rss/articles/CBMiWGh0dHBzOi8vd3d3Lm55dGltZXMuY29tLzIwMjQvMDMvMDUvdXMvZGFydG1vdXRoLWJhc2tldGJhbGwtdW5pb24tYXRobGV0ZXMtZW1wbG95ZWVzLmh0bWzSAQA?oc=5
# Publish Date: Wed, 06 Mar 2024 03:27:40 GMT
#
# Title: Kylie Kelce reacts to husband's emotional retirement speech: 'Very, very sweet' - Fox News
# Sentiment Label: Positive
# Sentiment Score: 0.5984
# Link: https://news.google.?oc=5
# Publish Date: Wed, 06 Mar 2024 13:33:00 GMT
#
# Title: Scientists say they're closer to reviving mammoths. What could go wrong? - The Washington Post
# Sentiment Label: Negative
# Sentiment Score: -0.4767
# Link: https://news.google.com/rss/articles/CBMihgFodHRwczovL3d3dy53YXNoaW5ndG9ucG9zdC5jb20vY2xpbWF0ZS1lbnZpcm9ubWVudC8yMDI0LzAzLzA2L3NjaWVudGlzdHMtc2F5LXRoZXlyZS1zdGVwLWNsb3Nlci1yZXZpdmluZy1tYW1tb3Rocy13aGF0LWNvdWxkLWdvLXdyb25nL9IBAA?oc=5
# Publish Date: Wed, 06 Mar 2024 18:00:00 GMT
#
# Title: Arctic to Lose All its Ice Within Next Decade: Study | Vantage with Palki Sharma - Firstpost
# Sentiment Label: Negative
# Sentiment Score: -0.4019
# Link: https://news.google.com/rss/articles/CCAiC25fWlZ0V3ZWMHQ4mAEB?oc=5
# Publish Date: Wed, 06 Mar 2024 18:10:00 GMT
#
# Title: Juno's Groundbreaking Discovery: Surprising Oxygen Insights From Europa's Close Flyby - SciTechDaily
# Sentiment Label: Positive
# Sentiment Score: 0.2732
# Link: https://news.google.com/rss/articles/CBMibGh0dHBzOi8vc2NpdGVjaGRhaWx5LmNvbS9qdW5vcy1ncm91bmRicmVha2luZy1kaXNjb3Zlcnktc3VycHJpc2luZy1veHlnZW4taW5zaWdodHMtZnJvbS1ldXJvcGFzLWNsb3NlLWZseWJ5L9IBAA?oc=5
# Publish Date: Wed, 06 Mar 2024 08:48:05 GMT
#
# Title: NASA Concerned as Voyager 1 Sending Back Incomprehensible Code - Futurism
# Sentiment Label: Neutral
# Sentiment Score: 0.0
# Link: https://news.google.com/rss/articles/CBMiQmh0dHBzOi8vZnV0dXJpc20uY29tL3RoZS1ieXRlL25hc2Etdm95YWdlci0xLWluY29tcHJlaGVuc2libGUtY29kZdIBAA?oc=5
# Publish Date: Wed, 06 Mar 2024 17:32:34 GMT
#
# Title: A man deliberately got 217 Covid shots. Here’s what happened - CNN
# Sentiment Label: Neutral
# Sentiment Score: 0.0
# Link: https://news.google.?oc=5
# Publish Date: Wed, 06 Mar 2024 16:16:00 GMT
#
# Title: Healthy Returns: What to know about CDC’s new Covid recommendations - CNBC
# Sentiment Label: Positive
# Sentiment Score: 0.4019
# Link: https://news.google.?oc=5
# Publish Date: Wed, 06 Mar 2024 17:08:59 GMT
#
# Title: COVID-19 leaves its mark on the brain, including with significant drops in IQ scores - PsyPost
# Sentiment Label: Positive
# Sentiment Score: 0.2023
# Link: https://news.google.com/rss/articles/CBMibGh0dHBzOi8vd3d3LnBzeXBvc3Qub3JnL2NvdmlkLTE5LWxlYXZlcy1pdHMtbWFyay1vbi10aGUtYnJhaW4taW5jbHVkaW5nLXdpdGgtc2lnbmlmaWNhbnQtZHJvcHMtaW4taXEtc2NvcmVzL9IBAA?oc=5
# Publish Date: Tue, 05 Mar 2024 19:01:53 GMT
#
# Title: American Indian Cancer Foundation Launches Sixth Annual Blue Beads Campaign for National Colorectal Cancer Awareness Month - Yahoo Life
# Sentiment Label: Negative
# Sentiment Score: -0.8689
# Link: https://news.google.com/rss/articles/CBMiWWh0dHBzOi8vd3d3LnlhaG9vLmNvbS9saWZlc3R5bGUvYW1lcmljYW4taW5kaWFuLWNhbmNlci1mb3VuZGF0aW9uLWxhdW5jaGVzLTEzMzMyMzk0NC5odG1s0gEA?oc=5
# Publish Date: Tue, 05 Mar 2024 13:33:23 GMT

# %%
from GoogleNews import GoogleNews

# Initialize GoogleNews object
googlenews = GoogleNews()

# Set the time period (optional)
googlenews.set_time_range('02/01/2023','03/01/2023')

# Set the language and region (optional)
#googlenews.set_lang('en')
#googlenews.set_region('US')

# Search for news items containing "Mark Zuckerberg"
googlenews.search('Mark Zuckerberg')

# Get the result
result = googlenews.results()

# Print the result
for news in result:
    print(f"Title: {news['title']}")
    print(f"Media: {news['media']}")
    print(f"Date: {news['date']}")
    print(f"Link: {news['link']}")
    print("-" * 60)
# Out:
# Title: Gravitas | Meta Blackout: How much money did Mark Zuckerberg lose?
# Media: WION
# Date: 2 hours ago
# Link: https://www.wionews.com/videos/gravitas-meta-blackout-how-much-money-did-mark-zuckerberg-lose-697417&ved=2ahUKEwixps3EyuCEAxVsLEQIHZPADQEQxfQBegQIAxAC&usg=AOvVaw0nSry4GCRfyl3UNIRjST6T
# ------------------------------------------------------------
# Title: Mark Zuckerberg loses $3 billion after Meta outage
# Media: WION
# Date: 2 hours ago
# Link: https://www.wionews.com/videos/mark-zuckerberg-loses-3-billion-after-meta-outage-697410&ved=2ahUKEwixps3EyuCEAxVsLEQIHZPADQEQxfQBegQICRAC&usg=AOvVaw0DanOKQS583rZ24ZM0rJOw
# ------------------------------------------------------------
# Title: Mark Zuckerberg loses $3 billion after Meta outage | WION News
# Media: YouTube
# Date: 2 hours ago
# Link: https://www.youtube.com/watch%3Fv%3DKIzuYCKh5r8&ved=2ahUKEwixps3EyuCEAxVsLEQIHZPADQEQxfQBegQIBBAC&usg=AOvVaw0aVs0W0yd3_-oykvQ3vm8V
# ------------------------------------------------------------
# Title: Billionaire Bunker With A Flaming Moat And Drawbridge? How Billionaires Like Mark Zuckerberg Are Taking Serious ...
# Media: Yahoo Finance
# Date: 3 hours ago
# Link: https://finance.yahoo.com/news/billionaire-bunker-flaming-moat-drawbridge-182914711.html&ved=2ahUKEwixps3EyuCEAxVsLEQIHZPADQEQxfQBegQIABAC&usg=AOvVaw3IqqzB_nWvwFZxVGUZEPE0
# ------------------------------------------------------------
# Title: Elon Musk Mocks Zuckerberg Amid Meta's Facebook, Instagram Outage
# Media: BNN Breaking
# Date: 3 hours ago
# Link: https://bnnbreaking.com/world/nigeria/elon-musk-mocks-zuckerberg-amid-metas-facebook-instagram-outage&ved=2ahUKEwixps3EyuCEAxVsLEQIHZPADQEQxfQBegQIBRAC&usg=AOvVaw22ZGkwt24sjZ17HiXmCujg
# ------------------------------------------------------------
# Title: Mark Zuckerberg Impressed by Anant Ambani's Luxury Watch at Pre-Wedding Celebration
# Media: PressWire18
# Date: 3 hours ago
# Link: https://presswire18.com/mark-zuckerberg-impressed-by-anant-ambanis-luxury-watch-at-pre-wedding-celebration/&ved=2ahUKEwixps3EyuCEAxVsLEQIHZPADQEQxfQBegQIAhAC&usg=AOvVaw3-875QwlaM8SpX_Bza1eDu
# ------------------------------------------------------------
# Title: The Price of Downtime: How Much Did Mark Zuckerberg Lose? | Facebook | Instagram
# Media: YouTube
# Date: 3 hours ago
# Link: https://www.youtube.com/watch%3Fv%3DUmwpEEOV6bM&ved=2ahUKEwixps3EyuCEAxVsLEQIHZPADQEQxfQBegQIBxAC&usg=AOvVaw0waBF8lbOXp_FuqO_PyhPc
# ------------------------------------------------------------
# Title: Facebook Parent Meta May Set Up Data Centre In India: Report
# Media: ABP News
# Date: 3 hours ago
# Link: https://news.abplive.com/technology/meta-india-data-centre-instagram-reels-mark-zuckerberg-1670025&ved=2ahUKEwixps3EyuCEAxVsLEQIHZPADQEQxfQBegQIBhAC&usg=AOvVaw1mdEIeeyha8RErtsYpkYX7
# ------------------------------------------------------------
# Title: Mark Zuckerberg building $270 Million self-sufficient compound in Hawaii? Here's why
# Media: ET Now
# Date: 3 hours ago
# Link: https://www.etnownews.com/news/mark-zuckerberg-building-270-million-self-sufficient-compound-in-hawaii-heres-why-article-108276019&ved=2ahUKEwixps3EyuCEAxVsLEQIHZPADQEQxfQBegQIARAC&usg=AOvVaw3B11BYodWr8uZugcQkPSf3
# ------------------------------------------------------------
# Title: Global outage takes toll on Meta's finances: millions lost in a day
# Media: Hum NEWS
# Date: 4 hours ago
# Link: https://humnews.pk/technology/meta-outage-loss/&ved=2ahUKEwixps3EyuCEAxVsLEQIHZPADQEQxfQBegQICBAC&usg=AOvVaw1KPwkzzRHupQ9CxUZUp6Ug
# ------------------------------------------------------------

# %%
from GoogleNews import GoogleNews
from textblob import TextBlob
from datetime import datetime
import nltk
from nltk import word_tokenize, pos_tag

# Download NLTK resources
nltk.download('punkt')
nltk.download('averaged_perceptron_tagger')

# Initialize GoogleNews object
googlenews = GoogleNews()

# Set the time period (optional)
googlenews.set_time_range('02/01/2023','03/01/2024')

# Set the language and region (optional)
# googlenews.set_lang('en')
# googlenews.set_region('US')

# Search for news items containing a target of interest
googlenews.search('climate change')
googlenews.get_page(5)
# Get the result
result = googlenews.results()

# Function to perform sentiment analysis
def analyze_sentiment(text):
    analysis = TextBlob(text)
    # Get the sentiment polarity score
    sentiment_score = analysis.sentiment.polarity
    # Assigning sentiment label based on polarity score
    if sentiment_score > 0:
        sentiment_label = 'Positive'
    elif sentiment_score == 0:
        sentiment_label = 'Neutral'
    else:
        sentiment_label = 'Negative'
    return sentiment_label, sentiment_score

# Function to extract nouns from the headline
def extract_nouns_from_headline(headline):
    tokens = word_tokenize(headline)
    tagged = pos_tag(tokens)
    nouns = [word for word, pos in tagged if pos.startswith('NN')]
    return nouns

# Function to infer topic from the headline
def infer_topic(headline):
    # Use a simple keyword extraction approach
    keywords = {
        'business': ['business', 'stock', 'market', 'finance', 'economy', 'company', 'industry'],
        'technology': ['technology', 'tech', 'innovation', 'digital', 'internet'],
        'politics': ['politics', 'government', 'election', 'policy', 'administration'],
        'sports': ['sports', 'athletics', 'games', 'football', 'basketball', 'soccer'],
        'entertainment': ['entertainment', 'celebrity', 'film', 'music', 'showbiz', 'hollywood'],
        'health': ['health', 'medicine', 'wellness', 'medical', 'fitness'],
        'science': ['science', 'research', 'discovery', 'innovation', 'experiment'],
        'poor_performance': ['poor performance', 'decline', 'struggle', 'losses', 'failure', 'outage'],
        'other': ['other', 'miscellaneous', 'general']
    }
    
    for topic, keywords_list in keywords.items():
        for keyword in keywords_list:
            if keyword in headline.lower():
                return topic
    return 'Other'

# Print the result with sentiment analysis and inferred topic
for news in result:
    headline = news['title']
    sentiment_label, sentiment_score = analyze_sentiment(headline)
    nouns = extract_nouns_from_headline(headline)
    topic = infer_topic(headline)
    print("Title:", headline)
    print("Sentiment Label:", sentiment_label)
    print("Sentiment Score:", sentiment_score)
    print("Nouns:", nouns)
    print("Topic:", topic)
    print("Media:", news['media'])
    print("Date:", news['date'])
    print("Link:", news['link'])
    print("-" * 60)
# Out:
# [nltk_data] Downloading package punkt to
# [nltk_data]     C:\Users\DonGaspar\AppData\Roaming\nltk_data...
# [nltk_data]   Package punkt is already up-to-date!
# [nltk_data] Downloading package averaged_perceptron_tagger to
# [nltk_data]     C:\Users\DonGaspar\AppData\Roaming\nltk_data...
# [nltk_data]   Package averaged_perceptron_tagger is already up-to-
# [nltk_data]       date!
# Title: This satellite could help fight climate change | March 6, 2024
# Sentiment Label: Neutral
# Sentiment Score: 0.0
# Nouns: ['satellite', 'climate', 'change', '|', 'March']
# Topic: Other
# Media: YouTube
# Date: 5 minutes ago
# Link: https://www.youtube.com/watch%3Fv%3DhVZKPqCUedQ&ved=2ahUKEwj30uuMz-CEAxVgm68BHVAZAAMQxfQBegQIARAC&usg=AOvVaw0QljIGpq3RIFiyMWLsRA8C
# ------------------------------------------------------------
# Title: SEC signs off on landmark climate rule as legal backlash looms
# Sentiment Label: Positive
# Sentiment Score: 0.05
# Nouns: ['SEC', 'signs', 'landmark', 'climate', 'rule', 'backlash', 'looms']
# Topic: Other
# Media: Politico
# Date: 5 minutes ago
# Link: https://www.politico.com/news/2024/03/06/sec-set-to-launch-landmark-climate-rule-sparking-legal-blitz-00145323&ved=2ahUKEwj30uuMz-CEAxVgm68BHVAZAAMQxfQBegQICRAC&usg=AOvVaw0_gk-XEFXrFDUypnvGdZsn
# ------------------------------------------------------------
# Title: US SEC adopts climate rule that may face challenges despite dilution
# Sentiment Label: Negative
# Sentiment Score: -0.1
# Nouns: ['US', 'SEC', 'climate', 'rule', 'challenges', 'dilution']
# Topic: Other
# Media: Reuters
# Date: 5 minutes ago
# Link: https://www.reuters.com/sustainability/boards-policy-regulation/us-sec-vote-long-awaited-overhaul-corporate-climate-disclosure-rules-2024-03-06/&ved=2ahUKEwj30uuMz-CEAxVgm68BHVAZAAMQxfQBegQIBBAC&usg=AOvVaw3wRIW6-WvoNmWBeGFR3apE
# ------------------------------------------------------------
# Title: Allergies: Symptoms begin early for some in Canada
# Sentiment Label: Positive
# Sentiment Score: 0.1
# Nouns: ['Allergies', 'Symptoms', 'Canada']
# Topic: Other
# Media: CTV News
# Date: 1 hour ago
# Link: https://www.ctvnews.ca/canada/symptoms-are-starting-early-for-allergy-sufferers-in-canada-some-say-climate-change-is-to-blame-1.6797035&ved=2ahUKEwj30uuMz-CEAxVgm68BHVAZAAMQxfQBegQIABAC&usg=AOvVaw3lDYo0wJc8Dktl6bz6amkd
# ------------------------------------------------------------
# Title: SEC votes to require company climate disclosures with scaled-back rule
# Sentiment Label: Negative
# Sentiment Score: -0.1
# Nouns: ['SEC', 'company', 'climate', 'disclosures', 'rule']
# Topic: business
# Media: Financial Times
# Date: 2 hours ago
# Link: https://www.ft.com/content/8ba7ca8b-6ffa-4b19-b2bb-8acfd7dd83eb&ved=2ahUKEwj30uuMz-CEAxVgm68BHVAZAAMQxfQBegQIBRAC&usg=AOvVaw2I-jGCYl075GjzdMBKpPbw
# ------------------------------------------------------------
# Title: SEC climate change disclosure rule touches off Hill fireworks
# Sentiment Label: Negative
# Sentiment Score: -0.1
# Nouns: ['SEC', 'climate', 'change', 'disclosure', 'rule', 'touches', 'Hill', 'fireworks']
# Topic: Other
# Media: Axios
# Date: 2 hours ago
# Link: https://www.axios.com/pro/energy-policy/2024/03/06/climate-disclosure-rules-fireworks&ved=2ahUKEwj30uuMz-CEAxVgm68BHVAZAAMQxfQBegQICBAC&usg=AOvVaw2hHj2qJq2ypVEFUUGO7Xvi
# ------------------------------------------------------------
# Title: Ontario bracing for climate change to ‘express itself’ in ‘new and unique’ ways
# Sentiment Label: Positive
# Sentiment Score: 0.2556818181818182
# Nouns: ['Ontario', 'climate', 'change', '‘', '’', 'ways']
# Topic: Other
# Media: Global News
# Date: 2 hours ago
# Link: https://globalnews.ca/news/10337142/ontario-climate-change-forest-fires-2024/&ved=2ahUKEwj30uuMz-CEAxVgm68BHVAZAAMQxfQBegQIBxAC&usg=AOvVaw3BNDABLczJnE_K9g8s0baZ
# ------------------------------------------------------------
# Title: Climate Change May Unearth Cold War-Era Nuclear Waste Stored by the U.S. in Other Countries
# Sentiment Label: Negative
# Sentiment Score: -0.30833333333333335
# Nouns: ['Climate', 'Change', 'May', 'Unearth', 'Cold', 'Nuclear', 'Waste', 'Stored', 'U.S.', 'Countries']
# Topic: other
# Media: Smithsonian Magazine
# Date: 2 hours ago
# Link: https://www.smithsonianmag.com/smart-news/climate-change-may-unearth-cold-war-era-nuclear-waste-stored-by-the-us-in-other-countries-180983901/&ved=2ahUKEwj30uuMz-CEAxVgm68BHVAZAAMQxfQBegQIBhAC&usg=AOvVaw1dKhqL5Q6mdsqK-5kNCjKO
# ------------------------------------------------------------
# Title: Culture wars on climate change at odds with Florida voters
# Sentiment Label: Neutral
# Sentiment Score: 0.0
# Nouns: ['Culture', 'wars', 'climate', 'change', 'odds', 'Florida', 'voters']
# Topic: Other
# Media: Florida Politics
# Date: 2 hours ago
# Link: https://floridapolitics.com/archives/663732-culture-wars-on-climate-change-at-odds-with-florida-voters/&ved=2ahUKEwj30uuMz-CEAxVgm68BHVAZAAMQxfQBegQIAhAC&usg=AOvVaw1G60CZu-T9JgyYtp4G-YU_
# ------------------------------------------------------------
# Title: US ski industry lost over $5B in past 20 years due to climate change
# Sentiment Label: Negative
# Sentiment Score: -0.1875
# Nouns: ['US', 'industry', 'years', 'change']
# Topic: business
# Media: WTXL ABC 27
# Date: 3 hours ago
# Link: https://www.wtxl.com/us-ski-industry-lost-over-5b-in-past-20-years-due-to-climate-change&ved=2ahUKEwj30uuMz-CEAxVgm68BHVAZAAMQxfQBegQIAxAC&usg=AOvVaw3jnUlqcnWwGyKowjMpdQj8
# ------------------------------------------------------------
# Title: Marcos pushes Philippines-Australia partnership on climate change
# Sentiment Label: Neutral
# Sentiment Score: 0.0
# Nouns: ['Marcos', 'Philippines-Australia', 'partnership', 'climate', 'change']
# Topic: Other
# Media: Philstar.com
# Date: 5 hours ago
# Link: https://qa.philstar.com/business/2024/03/07/2338586/marcos-pushes-philippines-australia-partnership-climate-change&ved=2ahUKEwjPt5-Nz-CEAxUIma8BHR4XCp44KBDF9AF6BAgEEAI&usg=AOvVaw3JdwRKo2AJTIfHwgNY6mKs
# ------------------------------------------------------------
# Title: 50% of Bangladesh’s RMG workforce affected by climate change: Study
# Sentiment Label: Neutral
# Sentiment Score: 0.0
# Nouns: ['%', 'Bangladesh', '’', 'RMG', 'workforce', 'climate', 'change', 'Study']
# Topic: Other
# Media: The Business Standard
# Date: 5 hours ago
# Link: https://www.tbsnews.net/node/804786&ved=2ahUKEwjPt5-Nz-CEAxUIma8BHR4XCp44KBDF9AF6BAgJEAI&usg=AOvVaw0qw2lag5NhvZjITwYdNAHB
# ------------------------------------------------------------
# Title: SEC eyes new rules to force more corporate climate disclosures
# Sentiment Label: Positive
# Sentiment Score: 0.1340909090909091
# Nouns: ['SEC', 'rules', 'climate', 'disclosures']
# Topic: Other
# Media: Axios
# Date: 6 hours ago
# Link: https://www.axios.com/2024/03/06/sec-climate-disclosures&ved=2ahUKEwjPt5-Nz-CEAxUIma8BHR4XCp44KBDF9AF6BAgBEAI&usg=AOvVaw0LFQIiSRGcr_8Qtc5I-Hnb
# ------------------------------------------------------------
# Title: Amideast and Boeing empower students to tackle climate change
# Sentiment Label: Neutral
# Sentiment Score: 0.0
# Nouns: ['Amideast', 'Boeing', 'students', 'climate', 'change']
# Topic: Other
# Media: Gulf News
# Date: 6 hours ago
# Link: https://gulfnews.com/friday/friday-partner/amideast-and-boeing-empower-students-to-tackle-climate-change-1.1709740751227&ved=2ahUKEwjPt5-Nz-CEAxUIma8BHR4XCp44KBDF9AF6BAgIEAI&usg=AOvVaw3CcgZ6_ybtY487TVb_uRlR
# ------------------------------------------------------------
# Title: Solar Radiation Modification: Why this 'science-fiction' climate hack was rejected at UNEA 6
# Sentiment Label: Neutral
# Sentiment Score: 0.0
# Nouns: ['Radiation', 'Modification', "'science-fiction", 'climate', 'hack', 'UNEA']
# Topic: science
# Media: Nation
# Date: 6 hours ago
# Link: https://nation.africa/kenya/news/solar-radiation-modification-why-this-science-fiction-climate-hack-was-rejected-at-unea-6-4547200&ved=2ahUKEwjPt5-Nz-CEAxUIma8BHR4XCp44KBDF9AF6BAgCEAI&usg=AOvVaw1R8wNO_virezzv37nO5xWN
# ------------------------------------------------------------
# Title: MIT Sloan to launch new climate policy center with $25 million investment
# Sentiment Label: Positive
# Sentiment Score: 0.018181818181818174
# Nouns: ['MIT', 'Sloan', 'climate', 'policy', 'center', 'investment']
# Topic: politics
# Media: MIT Sloan
# Date: 6 hours ago
# Link: https://mitsloan.mit.edu/press/mit-sloan-to-launch-new-climate-policy-center-25-million-investment&ved=2ahUKEwjPt5-Nz-CEAxUIma8BHR4XCp44KBDF9AF6BAgHEAI&usg=AOvVaw3OMfjwPKR6VVYrU4P1rYM2
# ------------------------------------------------------------
# Title: The One Big Change to the SEC's Climate Rule
# Sentiment Label: Negative
# Sentiment Score: -0.05
# Nouns: ['Big', 'Change', 'SEC', 'Climate', 'Rule']
# Topic: Other
# Media: Heatmap News
# Date: 6 hours ago
# Link: https://heatmap.news/economy/sec-climate-disclosure-change&ved=2ahUKEwjPt5-Nz-CEAxUIma8BHR4XCp44KBDF9AF6BAgFEAI&usg=AOvVaw3NJ43p--RSjJMnZwpNMaeY
# ------------------------------------------------------------
# Title: S.E.C. Approves New Climate Rules Far Weaker Than Originally Proposed
# Sentiment Label: Positive
# Sentiment Score: 0.20378787878787877
# Nouns: ['S.E.C', 'New', 'Climate', 'Rules', 'Far', 'Weaker', 'Than']
# Topic: Other
# Media: The New York Times
# Date: 7 hours ago
# Link: https://www.nytimes.com/2024/03/06/climate/sec-climate-disclosure-regulations.html&ved=2ahUKEwjPt5-Nz-CEAxUIma8BHR4XCp44KBDF9AF6BAgAEAI&usg=AOvVaw2K1J3sOU_HOYVWjGYA-362
# ------------------------------------------------------------
# Title: How Climate Change is Exposing Hidden Dangers of Past Nuclear Tests
# Sentiment Label: Negative
# Sentiment Score: -0.20833333333333331
# Nouns: ['Climate', 'Change', 'Hidden', 'Dangers', 'Past', 'Nuclear', 'Tests']
# Topic: Other
# Media: One Green Planet
# Date: 7 hours ago
# Link: https://www.onegreenplanet.org/environment/how-climate-change-is-exposing-hidden-dangers-of-past-nuclear-tests/&ved=2ahUKEwjPt5-Nz-CEAxUIma8BHR4XCp44KBDF9AF6BAgDEAI&usg=AOvVaw0TGeplPOhXub_yP9KT2aj_
# ------------------------------------------------------------
# Title: BNP Paribas: The best bank to work for if you want to fight climate change?
# Sentiment Label: Positive
# Sentiment Score: 1.0
# Nouns: ['BNP', 'Paribas', 'bank', 'climate', 'change']
# Topic: Other
# Media: eFinancialCareers
# Date: 7 hours ago
# Link: https://www.efinancialcareers.com/news/bnp-paribas-enviroment-esg&ved=2ahUKEwjPt5-Nz-CEAxUIma8BHR4XCp44KBDF9AF6BAgGEAI&usg=AOvVaw3o4J7iCrLWQyiYpRhl94-H
# ------------------------------------------------------------

# %%
# Out:
# [nltk_data] Downloading package punkt to
# [nltk_data]     C:\Users\DonGaspar\AppData\Roaming\nltk_data...
# [nltk_data]   Package punkt is already up-to-date!
# [nltk_data] Downloading package averaged_perceptron_tagger to
# [nltk_data]     C:\Users\DonGaspar\AppData\Roaming\nltk_data...
# [nltk_data]   Package averaged_perceptron_tagger is already up-to-
# [nltk_data]       date!
# Title: Gravitas | Meta Blackout: How much money did Mark Zuckerberg lose?
# Sentiment Label: Positive
# Sentiment Score: 0.2
# Nouns: ['Gravitas', '|', 'Meta', 'Blackout', 'money', 'Mark', 'Zuckerberg']
# Topic: Other
# Summary:
# Media: WION
# Date: 2 hours ago
# Link: https://www.wionews.com/videos/gravitas-meta-blackout-how-much-money-did-mark-zuckerberg-lose-697417&ved=2ahUKEwivpMPVzuCEAxX5na8BHWWoCUgQxfQBegQIBBAC&usg=AOvVaw3ngtVckufvGEFRW6vG9K51
# ------------------------------------------------------------
# Title: Mark Zuckerberg loses $3 billion after Meta outage
# Sentiment Label: Negative
# Sentiment Score: -0.3
# Nouns: ['Mark', 'Zuckerberg', 'Meta', 'outage']
# Topic: poor_performance
# Summary:
# Media: WION
# Date: 3 hours ago
# Link: https://www.wionews.com/videos/mark-zuckerberg-loses-3-billion-after-meta-outage-697410&ved=2ahUKEwivpMPVzuCEAxX5na8BHWWoCUgQxfQBegQICRAC&usg=AOvVaw0RsP5f04UUt5nplrf9NwCz
# ------------------------------------------------------------
# Title: Mark Zuckerberg loses $3 billion after Meta outage | WION News
# Sentiment Label: Negative
# Sentiment Score: -0.3
# Nouns: ['Mark', 'Zuckerberg', 'Meta', 'outage', '|', 'WION', 'News']
# Topic: poor_performance
# Summary:
# Media: YouTube
# Date: 3 hours ago
# Link: https://www.youtube.com/watch%3Fv%3DKIzuYCKh5r8&ved=2ahUKEwivpMPVzuCEAxX5na8BHWWoCUgQxfQBegQIARAC&usg=AOvVaw3YR5vovLl8KED83OiLfDI1
# ------------------------------------------------------------
# Title: Billionaire Bunker With A Flaming Moat And Drawbridge? How Billionaires Like Mark Zuckerberg Are Taking Serious ...
# Sentiment Label: Negative
# Sentiment Score: -0.3333333333333333
# Nouns: ['Billionaire', 'Bunker', 'A', 'Flaming', 'Moat', 'Drawbridge', 'Billionaires', 'Mark', 'Zuckerberg', 'Are', 'Taking', 'Serious']
# Topic: Other
# Summary:
# Media: Yahoo Finance
# Date: 3 hours ago
# Link: https://finance.yahoo.com/news/billionaire-bunker-flaming-moat-drawbridge-182914711.html&ved=2ahUKEwivpMPVzuCEAxX5na8BHWWoCUgQxfQBegQIAhAC&usg=AOvVaw2Q6EgP9H9zuCkn-7egJl2c
# ------------------------------------------------------------
# Title: Elon Musk Mocks Zuckerberg Amid Meta's Facebook, Instagram Outage
# Sentiment Label: Neutral
# Sentiment Score: 0.0
# Nouns: ['Elon', 'Musk', 'Mocks', 'Zuckerberg', 'Amid', 'Meta', 'Facebook', 'Instagram', 'Outage']
# Topic: poor_performance
# Summary:
# Media: BNN Breaking
# Date: 3 hours ago
# Link: https://bnnbreaking.com/world/nigeria/elon-musk-mocks-zuckerberg-amid-metas-facebook-instagram-outage&ved=2ahUKEwivpMPVzuCEAxX5na8BHWWoCUgQxfQBegQICBAC&usg=AOvVaw1WGDKrveKVhTHdcx0cQ-js
# ------------------------------------------------------------
# Title: Mark Zuckerberg Impressed by Anant Ambani's Luxury Watch at Pre-Wedding Celebration
# Sentiment Label: Positive
# Sentiment Score: 1.0
# Nouns: ['Mark', 'Zuckerberg', 'Anant', 'Ambani', 'Luxury', 'Watch', 'Pre-Wedding', 'Celebration']
# Topic: Other
# Summary:
# Media: PressWire18
# Date: 3 hours ago
# Link: https://presswire18.com/mark-zuckerberg-impressed-by-anant-ambanis-luxury-watch-at-pre-wedding-celebration/&ved=2ahUKEwivpMPVzuCEAxX5na8BHWWoCUgQxfQBegQIBhAC&usg=AOvVaw3f-FaTxxtTOUBFHInPBh2e
# ------------------------------------------------------------
# Title: The Price of Downtime: How Much Did Mark Zuckerberg Lose? | Facebook | Instagram
# Sentiment Label: Positive
# Sentiment Score: 0.2
# Nouns: ['Price', 'Downtime', 'Did', 'Mark', 'Zuckerberg', 'Lose', '|', 'Facebook', '|', 'Instagram']
# Topic: Other
# Summary:
# Media: YouTube
# Date: 3 hours ago
# Link: https://www.youtube.com/watch%3Fv%3DUmwpEEOV6bM&ved=2ahUKEwivpMPVzuCEAxX5na8BHWWoCUgQxfQBegQIABAC&usg=AOvVaw3-xb_Ykzx7M-6UJsCoMQWv
# ------------------------------------------------------------
# Title: Facebook Parent Meta May Set Up Data Centre In India: Report
# Sentiment Label: Neutral
# Sentiment Score: 0.0
# Nouns: ['Facebook', 'Parent', 'Meta', 'May', 'Set', 'Up', 'Data', 'Centre', 'India', 'Report']
# Topic: Other
# Summary:
# Media: ABP News
# Date: 4 hours ago
# Link: https://news.abplive.com/technology/meta-india-data-centre-instagram-reels-mark-zuckerberg-1670025&ved=2ahUKEwivpMPVzuCEAxX5na8BHWWoCUgQxfQBegQIBRAC&usg=AOvVaw0qGhp6oeDLtxO-xEXL7je5
# ------------------------------------------------------------
# Title: Mark Zuckerberg building $270 Million self-sufficient compound in Hawaii? Here's why
# Sentiment Label: Neutral
# Sentiment Score: 0.0
# Nouns: ['Mark', 'Zuckerberg', 'Million', 'compound', 'Hawaii']
# Topic: Other
# Summary:
# Media: ET Now
# Date: 4 hours ago
# Link: https://www.etnownews.com/news/mark-zuckerberg-building-270-million-self-sufficient-compound-in-hawaii-heres-why-article-108276019&ved=2ahUKEwivpMPVzuCEAxX5na8BHWWoCUgQxfQBegQIAxAC&usg=AOvVaw00IY_4l1TInNuktoel1PVl
# ------------------------------------------------------------
# Title: Global outage takes toll on Meta's finances: millions lost in a day
# Sentiment Label: Neutral
# Sentiment Score: 0.0
# Nouns: ['outage', 'toll', 'Meta', 'finances', 'millions', 'day']
# Topic: business
# Summary:
# Media: Hum NEWS
# Date: 4 hours ago
# Link: https://humnews.pk/technology/meta-outage-loss/&ved=2ahUKEwivpMPVzuCEAxX5na8BHWWoCUgQxfQBegQIBxAC&usg=AOvVaw1iwKTZxUmFgJhJU3sy8lYr
# ------------------------------------------------------------
